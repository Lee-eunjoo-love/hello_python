# %%
print("Hello, world")
print(10 + 20)
print(len("Hello"))
print(["A", "B", "C"])
print({"짜장": 5000, "짬뽕": 6000, "탕수육": 12000})
say_hello = "Hello, Python"
print(say_hello)
print("Hello", end=", ")
print("World")
foo = input("Enter something: ")
print(len(foo))

# %%
height=int(input("키입력(cm): "))
weight=int(input("몸무게입력(kg): "))
bmi=round(weight/((height/100)**2),2)
print("당신의BMI(체질량지수):", bmi, "입니다.")
